# %% [markdown]
# # lego_sets.csv
# - set_num: A code that is unique to each set in the dataset. This column is critical, and a missing value indicates the set is a duplicate or invalid!
# - set_name: A name for every set in the dataset (note that this can be the same for different sets).
# - year: The date the set was released.
# - num_parts: The number of parts contained in the set. This column is not central to our analyses, so missing values are acceptable.
# - theme_name: The name of the sub-theme of the set.
# - parent_theme: The name of the parent theme the set belongs to. Matches the `name` column of the `parent_themes` csv file.
# # parent_themes.csv
# - id: A code that is unique to every theme.
# - name: The name of the parent theme.
# - is_licensed: A Boolean column specifying whether the theme is a licensed theme.

# %%
import pandas as pd

# %%
lego_set = pd.read_csv(r'C:\Users\Asus\Desktop\Project\Python\Untitled Folder\lego_sets.csv')
parent_themes = pd.read_csv(r'C:\Users\Asus\Desktop\Project\Python\Untitled Folder\parent_themes.csv')

# %% [markdown]
# ## Cleaning datasets

# %%
lego_set.shape
# Out:
# (11986, 6)

# %%
lego_set.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
lego_copy = lego_set.copy()

# %%
lego_copy = lego_copy[lego_copy['set_num'].notnull()]

# %%
lego_copy.isnull().sum()
# Out:
# set_num            0
# name               0
# year               0
# num_parts       4998
# theme_name         0
# parent_theme       0
# dtype: int64

# %%
lego_copy.dtypes
# Out:
# set_num          object
# name             object
# year              int64
# num_parts       float64
# theme_name       object
# parent_theme     object
# dtype: object

# %%
parent_themes
# Out:
#       id          name  is_licensed
# 0      1       Technic        False
# 1     22       Creator        False
# 2     50          Town        False
# 3    112        Racers        False
# 4    126         Space        False
# ..   ...           ...          ...
# 106  605  Nexo Knights        False
# 107  606   Angry Birds         True
# 108  607  Ghostbusters         True
# 109  608        Disney         True
# 110  610    Brickheadz        False
#
# [111 rows x 3 columns]

# %%
parent_themes.isnull().sum()
# Out:
# id             0
# name           0
# is_licensed    0
# dtype: int64

# %%
parent_themes.dtypes
# Out:
# id              int64
# name           object
# is_licensed      bool
# dtype: object

# %%
data = pd.merge(left=lego_copy, right=parent_themes, left_on='parent_theme', right_on='name')
data
# Out:
#       set_num                             name_x  year  num_parts theme_name  \
# 0        00-1                    Weetabix Castle  1970      471.0     Castle
# 1        00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2        00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3        00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4        00-7  Weetabix Promotional Lego Village  1976        NaN   Building
# ...       ...                                ...   ...        ...        ...
# 11828  8410-1                          Swampfire  2010       22.0     Ben 10
# 11829  8411-1                        ChromaStone  2010       21.0     Ben 10
# 11830  8517-1                       Humungousaur  2010       14.0     Ben 10
# 11831  8518-1                            Jet Ray  2010        NaN     Ben 10
# 11832  8519-1                          Big Chill  2010       20.0     Ben 10
#
#       parent_theme   id    name_y  is_licensed
# 0         Legoland  411  Legoland        False
# 1         Legoland  411  Legoland        False
# 2         Legoland  411  Legoland        False
# 3         Legoland  411  Legoland        False
# 4         Legoland  411  Legoland        False
# ...            ...  ...       ...          ...
# 11828       Ben 10  270    Ben 10         True
# 11829       Ben 10  270    Ben 10         True
# 11830       Ben 10  270    Ben 10         True
# 11831       Ben 10  270    Ben 10         True
# 11832       Ben 10  270    Ben 10         True
#
# [11833 rows x 9 columns]

# %% [markdown]
# ## Task 1: What percentage of all licensed sets ever released were Star Wars Themed?|

# %%
subset = data.drop(columns=['num_parts', 'id', 'name_y'])
subset
# Out:
#       set_num                             name_x  year theme_name  \
# 0        00-1                    Weetabix Castle  1970     Castle
# 1        00-2       Weetabix Promotional House 1  1976   Building
# 2        00-3       Weetabix Promotional House 2  1976   Building
# 3        00-4      Weetabix Promotional Windmill  1976   Building
# 4        00-7  Weetabix Promotional Lego Village  1976   Building
# ...       ...                                ...   ...        ...
# 11828  8410-1                          Swampfire  2010     Ben 10
# 11829  8411-1                        ChromaStone  2010     Ben 10
# 11830  8517-1                       Humungousaur  2010     Ben 10
# 11831  8518-1                            Jet Ray  2010     Ben 10
# 11832  8519-1                          Big Chill  2010     Ben 10
#
#       parent_theme  is_licensed
# 0         Legoland        False
# 1         Legoland        False
# 2         Legoland        False
# 3         Legoland        False
# 4         Legoland        False
# ...            ...          ...
# 11828       Ben 10         True
# 11829       Ben 10         True
# 11830       Ben 10         True
# 11831       Ben 10         True
# 11832       Ben 10         True
#
# [11833 rows x 6 columns]

# %%
total_licensed = subset[subset['is_licensed']==True]['set_num'].count()
star_wars_licensed = subset[(subset['is_licensed']==True) & (subset['parent_theme']=='Star Wars')].set_num.count()
pct = star_wars_licensed*100/total_licensed
int(pct)
# Out:
# 51

# %%
total_licensed = subset[subset['is_licensed']==True]
star_wars_licensed = subset[(subset['is_licensed']==True) & (subset['parent_theme']=='Star Wars')]
pct = int(100*star_wars_licensed.shape[0]/total_licensed.shape[0])
pct
# Out:
# 51

# %% [markdown]
# ## Task 2: In which year was Star Wars not the most popular licensed theme?
# ##### Step 1: Find the most popular licensed theme each year
# ##### Step 2: Compare and answer the question

# %%
licensed = subset[subset['is_licensed']==True]
licensed
# Out:
#        set_num                         name_x  year               theme_name  \
# 3493   10018-1                     Darth Maul  2001                Star Wars
# 3494   10019-1    Rebel Blockade Runner - UCS  2001  Star Wars Episode 4/5/6
# 3495   10026-1        Naboo Starfighter - UCS  2002      Star Wars Episode 1
# 3496   10030-1  Imperial Star Destroyer - UCS  2002  Star Wars Episode 4/5/6
# 3497   10123-1                     Cloud City  2003  Star Wars Episode 4/5/6
# ...        ...                            ...   ...                      ...
# 11828   8410-1                      Swampfire  2010                   Ben 10
# 11829   8411-1                    ChromaStone  2010                   Ben 10
# 11830   8517-1                   Humungousaur  2010                   Ben 10
# 11831   8518-1                        Jet Ray  2010                   Ben 10
# 11832   8519-1                      Big Chill  2010                   Ben 10
#
#       parent_theme  is_licensed
# 3493     Star Wars         True
# 3494     Star Wars         True
# 3495     Star Wars         True
# 3496     Star Wars         True
# 3497     Star Wars         True
# ...            ...          ...
# 11828       Ben 10         True
# 11829       Ben 10         True
# 11830       Ben 10         True
# 11831       Ben 10         True
# 11832       Ben 10         True
#
# [1179 rows x 6 columns]

# %%
#Find the most popular licensed theme each year => Groupby: year, parent_theme
licensed['count']=1
licensed_group = licensed.groupby(['year', 'parent_theme']).count().reset_index()
licensed_group.sort_values('count', ascending=False).drop_duplicates(['year']).sort_values('year')
#licensed_group.sort_values: sort values based on 'count' column and then drop duplicates (only remain the first occurrence cuz it is the max value) => the most popular licensed theme each year
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_20576\1085892891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   licensed['count']=1
#     year  parent_theme  set_num  name_x  theme_name  is_licensed  count
# 0   1999     Star Wars       13      13          13           13     13
# 2   2000     Star Wars       26      26          26           26     26
# 4   2001     Star Wars       14      14          14           14     14
# 6   2002     Star Wars       28      28          28           28     28
# 9   2003     Star Wars       32      32          32           32     32
# 12  2004     Star Wars       20      20          20           20     20
# 16  2005     Star Wars       28      28          28           28     28
# 20  2006     Star Wars       11      11          11           11     11
# 24  2007     Star Wars       16      16          16           16     16
# 28  2008     Star Wars       23      23          23           23     23
# 32  2009     Star Wars       39      39          39           39     39
# 36  2010     Star Wars       30      30          30           30     30
# 42  2011     Star Wars       32      32          32           32     32
# 47  2012     Star Wars       43      43          43           43     43
# 52  2013     Star Wars       35      35          35           35     35
# 59  2014     Star Wars       45      45          45           45     45
# 67  2015     Star Wars       58      58          58           58     58
# 76  2016     Star Wars       61      61          61           61     61
# 82  2017  Super Heroes       72      72          72           72     72

# %%
the_answer = 2017

# %% [markdown]
# ## Task 3: How many unique sets were released each year (1955-2017)?

# %%
subset.head(20)
# Out:
#    set_num                             name_x  year    theme_name  \
# 0     00-1                    Weetabix Castle  1970        Castle
# 1     00-2       Weetabix Promotional House 1  1976      Building
# 2     00-3       Weetabix Promotional House 2  1976      Building
# 3     00-4      Weetabix Promotional Windmill  1976      Building
# 4     00-7  Weetabix Promotional Lego Village  1976      Building
# 5   102A-1                   Front-End Loader  1970  Construction
# 6   102A-2                   Front-End Loader  1970  Construction
# 7     1-10       Mini-Wheel Model Maker No. 1  1971       Vehicle
# 8   1550-1           Sterling Super Caravelle  1972       Airport
# 9   1551-2           Sterling Luggage Carrier  1972       Airport
# 10  1552-2                Sterling Boeing 727  1974       Airport
# 11  1555-2           Sterling Airways Biplane  1978       Airport
# 12  1560-2               Lufthansa Boeing 727  1976       Airport
# 13  1562-3            Lufthansa Double-Decker  1976       Airport
# 14   157-3            Four Car Auto Transport  1970       Vehicle
# 15  1601-1                         Conveyance  1976  Construction
# 16  1610-2                   Martinair Cessna  1978       Airport
# 17  1611-2                     Martinair DC-9  1978       Airport
# 18    2-10       Mini-Wheel Model Maker No. 2  1971       Vehicle
# 19   248-2         Factory With Conveyor Belt  1971  Construction
#
#    parent_theme  is_licensed
# 0      Legoland        False
# 1      Legoland        False
# 2      Legoland        False
# 3      Legoland        False
# 4      Legoland        False
# 5      Legoland        False
# 6      Legoland        False
# 7      Legoland        False
# 8      Legoland        False
# 9      Legoland        False
# 10     Legoland        False
# 11     Legoland        False
# 12     Legoland        False
# 13     Legoland        False
# 14     Legoland        False
# 15     Legoland        False
# 16     Legoland        False
# 17     Legoland        False
# 18     Legoland        False
# 19     Legoland        False

# %%
subset.groupby('year').count().reset_index()[['year', 'set_num']]
# Out:
#     year  set_num
# 0   1950        7
# 1   1953        4
# 2   1954       14
# 3   1955       28
# 4   1956       12
# 5   1957       21
# 6   1958       42
# 7   1959        4
# 8   1960        3
# 9   1961       17
# 10  1962       40
# 11  1963       18
# 12  1964       11
# 13  1965       10
# 14  1966       89
# 15  1967       21
# 16  1968       25
# 17  1969       69
# 18  1970       29
# 19  1971       45
# 20  1972       38
# 21  1973       68
# 22  1974       39
# 23  1975       31
# 24  1976       68
# 25  1977       92
# 26  1978       73
# 27  1979       82
# 28  1980       88
# 29  1981       79
# 30  1982       76
# 31  1983       57
# 32  1984       76
# 33  1985      139
# 34  1986      123
# 35  1987      209
# 36  1988       68
# 37  1989      114
# 38  1990       85
# 39  1991      106
# 40  1992      115
# 41  1993      111
# 42  1994      128
# 43  1995      128
# 44  1996      144
# 45  1997      194
# 46  1998      325
# 47  1999      300
# 48  2000      327
# 49  2001      339
# 50  2002      447
# 51  2003      415
# 52  2004      371
# 53  2005      330
# 54  2006      283
# 55  2007      319
# 56  2008      349
# 57  2009      403
# 58  2010      444
# 59  2011      502
# 60  2012      615
# 61  2013      593
# 62  2014      715
# 63  2015      670
# 64  2016      608
# 65  2017      438
